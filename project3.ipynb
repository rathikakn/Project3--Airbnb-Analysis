# %%
# Import libraries
import pandas as pd
import numpy as np
import os
import json

# %%
# Read in the dataset
airbnb = pd.read_json('/Users/rathikakn/Desktop/Guvi/project3airbnb/sample_airbnb.json')

# %%
airbnb
# Out:
#            _id                            listing_url  \
# 0      1003530   https://www.airbnb.com/rooms/1003530
# 1     10133554  https://www.airbnb.com/rooms/10133554
# 2     10059872  https://www.airbnb.com/rooms/10059872
# 3     10084023  https://www.airbnb.com/rooms/10084023
# 4     10091713  https://www.airbnb.com/rooms/10091713
# ...        ...                                    ...
# 5550   9985696   https://www.airbnb.com/rooms/9985696
# 5551   9993190   https://www.airbnb.com/rooms/9993190
# 5552   9887054   https://www.airbnb.com/rooms/9887054
# 5553   9907907   https://www.airbnb.com/rooms/9907907
# 5554   9936016   https://www.airbnb.com/rooms/9936016
#
#                                                    name  \
# 0                   New York City - Upper West Side Apt
# 1                   Double and triple rooms Blue mosque
# 2                    Soho Cozy, Spacious and Convenient
# 3                     City center private room with bed
# 4      Surry Hills Studio - Your Perfect Base in Sydney
# ...                                                 ...
# 5550                                    Kadıköy-Altıyol
# 5551  Just Steps from the Ocean at Premier Platinum ...
# 5552                Quarry Bay fully furnished studio C
# 5553                         Large double room in Bondi
# 5554                        Alugo Apartamento na Tijuca
#
#                                                 summary  \
# 0
# 1
# 2     Clean, fully furnish, Spacious 1 bedroom flat ...
# 3     House is located 5mins walk from Sham Shui Po ...
# 4     This spacious, light filled studio has everyth...
# ...                                                 ...
# 5550  Kadıköy merkezde 2+1 dairem vardır.Çok kalabal...
# 5551  Relax Hawaiian Style in Gated Community on Oce...
# 5552   Newly renovated studio flat with full furniture.
# 5553  A bright large double room is available in a b...
# 5554  Apartamento amplo que acomoda 6 pessoas. Um qu...
#
#                                                   space  \
# 0     Murphy bed, optional second bedroom available....
# 1     We are on the central city  Blue mosque 5 minu...
# 2
# 3     The house is old fashion type, and paint the w...
# 4     Comfortable studio with a great layout. The ba...
# ...                                                 ...
# 5550
# 5551  ***NOTE: THE OCEAN INFINITY POOL ("POOL 1"0 WI...
# 5552
# 5553
# 5554
#
#                                             description  \
# 0     Murphy bed, optional second bedroom available....
# 1     We are on the central city  Blue mosque 5 minu...
# 2     Clean, fully furnish, Spacious 1 bedroom flat ...
# 3     House is located 5mins walk from Sham Shui Po ...
# 4     This spacious, light filled studio has everyth...
# ...                                                 ...
# 5550  Kadıköy merkezde 2+1 dairem vardır.Çok kalabal...
# 5551  Relax Hawaiian Style in Gated Community on Oce...
# 5552   Newly renovated studio flat with full furniture.
# 5553  A bright large double room is available in a b...
# 5554  Apartamento amplo que acomoda 6 pessoas. Um qu...
#
#                                   neighborhood_overview  \
# 0     Great neighborhood - many terrific restaurants...
# 1     Cankurtaran mahallesi akbıyık caddesi no 22 Su...
# 2
# 3     Cheapest food, electronic device, clothing and...
# 4     Surry Hills is a vibrant eclectic community an...
# ...                                                 ...
# 5550
# 5551  Location: Located at the south end of Lahaina ...
# 5552
# 5553
# 5554
#
#                                                   notes  \
# 0     My cat, Samantha, are in and out during the su...
# 1
# 2
# 3     Deposit of $1000 will be charged and will retu...
# 4     WiFi, Apple TV with Netflix App (for use with ...
# ...                                                 ...
# 5550
# 5551  Puamana Resort requires a $10/day resort fee w...
# 5552
# 5553
# 5554
#
#                                                 transit  \
# 0     Conveniently located near 1, 2, 3, B & C subwa...
# 1      Tram 5 minutes  metro 10 minutes  Bus 10 minutes
# 2
# 3     Close to 3 different MTR Station, Sham shui Po...
# 4     Travel Card 'Opal' travel cards work on all Sy...
# ...                                                 ...
# 5550
# 5551  You can walk to most attractions within Lahain...
# 5552
# 5553  The flat is exactly half way between the shops...
# 5554
#
#                                                  access  ... guests_included  \
# 0                                        New York City!  ...               1
# 1     We have bathroom,wc,İnternet in rooms and unde...  ...               1
# 2                                                        ...               1
# 3     Living Room , Kitchen and Toilet, All cooking ...  ...               1
# 4     You have full use of the entire studio and com...  ...               1
# ...                                                 ...  ...             ...
# 5550                                                     ...               1
# 5551  Guests will have access to the 3 pools in the ...  ...               1
# 5552                                                     ...               2
# 5553  Guests will have access to the full residence,...  ...               2
# 5554                                                     ...               1
#
#                                                  images  \
# 0     {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 1     {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 2     {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 3     {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 4     {'thumbnail_url': '', 'medium_url': '', 'pictu...
# ...                                                 ...
# 5550  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 5551  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 5552  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 5553  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 5554  {'thumbnail_url': '', 'medium_url': '', 'pictu...
#
#                                                    host  \
# 0     {'host_id': '454250', 'host_url': 'https://www...
# 1     {'host_id': '52004703', 'host_url': 'https://w...
# 2     {'host_id': '51624384', 'host_url': 'https://w...
# 3     {'host_id': '51744313', 'host_url': 'https://w...
# 4     {'host_id': '13764143', 'host_url': 'https://w...
# ...                                                 ...
# 5550  {'host_id': '51303748', 'host_url': 'https://w...
# 5551  {'host_id': '51013381', 'host_url': 'https://w...
# 5552  {'host_id': '31386255', 'host_url': 'https://w...
# 5553  {'host_id': '47615848', 'host_url': 'https://w...
# 5554  {'host_id': '47092481', 'host_url': 'https://w...
#
#                                                 address  \
# 0     {'street': 'New York, NY, United States', 'sub...
# 1     {'street': 'Fatih , İstanbul, Turkey', 'suburb...
# 2     {'street': 'Hong Kong, Hong Kong Island, Hong ...
# 3     {'street': 'Hong Kong , 九龍, Hong Kong', 'subur...
# 4     {'street': 'Surry Hills, NSW, Australia', 'sub...
# ...                                                 ...
# 5550  {'street': 'Kadıköy, İstanbul, Turkey', 'subur...
# 5551  {'street': 'Lahaina, HI, United States', 'subu...
# 5552  {'street': 'Hong Kong, Hong Kong Island, Hong ...
# 5553  {'street': 'Bondi Beach, NSW, Australia', 'sub...
# 5554  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
#
#                                            availability  \
# 0     {'availability_30': 0, 'availability_60': 0, '...
# 1     {'availability_30': 30, 'availability_60': 60,...
# 2     {'availability_30': 0, 'availability_60': 0, '...
# 3     {'availability_30': 14, 'availability_60': 24,...
# 4     {'availability_30': 0, 'availability_60': 0, '...
# ...                                                 ...
# 5550  {'availability_30': 30, 'availability_60': 60,...
# 5551  {'availability_30': 0, 'availability_60': 8, '...
# 5552  {'availability_30': 18, 'availability_60': 48,...
# 5553  {'availability_30': 0, 'availability_60': 0, '...
# 5554  {'availability_30': 0, 'availability_60': 0, '...
#
#                                           review_scores  \
# 0     {'review_scores_accuracy': 10, 'review_scores_...
# 1     {'review_scores_accuracy': 9, 'review_scores_c...
# 2     {'review_scores_accuracy': 10, 'review_scores_...
# 3     {'review_scores_accuracy': 10, 'review_scores_...
# 4     {'review_scores_accuracy': 10, 'review_scores_...
# ...                                                 ...
# 5550                                                 {}
# 5551  {'review_scores_accuracy': 10, 'review_scores_...
# 5552  {'review_scores_accuracy': 10, 'review_scores_...
# 5553                                                 {}
# 5554                                                 {}
#
#                                                 reviews weekly_price  \
# 0     [{'_id': '4351675', 'date': '2013-04-29 04:00:...          NaN
# 1     [{'_id': '149469150', 'date': '2017-05-04 04:0...          NaN
# 2     [{'_id': '56904633', 'date': '2015-12-19 05:00...       5000.0
# 3     [{'_id': '57191745', 'date': '2015-12-22 05:00...       1350.0
# 4     [{'_id': '123549502', 'date': '2016-12-29 05:0...          NaN
# ...                                                 ...          ...
# 5550                                                 []          NaN
# 5551  [{'_id': '68762225', 'date': '2016-04-06 04:00...          NaN
# 5552  [{'_id': '105800033', 'date': '2016-10-02 04:0...          NaN
# 5553                                                 []          NaN
# 5554                                                 []          NaN
#
#      monthly_price reviews_per_month
# 0              NaN               NaN
# 1              NaN               NaN
# 2              NaN               NaN
# 3           5000.0               NaN
# 4              NaN               NaN
# ...            ...               ...
# 5550           NaN               NaN
# 5551           NaN               NaN
# 5552           NaN               NaN
# 5553           NaN               NaN
# 5554           NaN               NaN
#
# [5555 rows x 42 columns]

# %%
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 42 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _id                    5555 non-null   int64
#  1   listing_url            5555 non-null   object
#  2   name                   5555 non-null   object
#  3   summary                5555 non-null   object
#  4   space                  5555 non-null   object
#  5   description            5555 non-null   object
#  6   neighborhood_overview  5555 non-null   object
#  7   notes                  5555 non-null   object
#  8   transit                5555 non-null   object
#  9   access                 5555 non-null   object
#  10  interaction            5555 non-null   object
#  11  house_rules            5555 non-null   object
#  12  property_type          5555 non-null   object
#  13  room_type              5555 non-null   object
#  14  bed_type               5555 non-null   object
#  15  minimum_nights         5555 non-null   int64
#  16  maximum_nights         5555 non-null   int64
#  17  cancellation_policy    5555 non-null   object
#  18  last_scraped           5555 non-null   object
#  19  calendar_last_scraped  5555 non-null   object
#  20  first_review           4167 non-null   object
#  21  last_review            4167 non-null   object
#  22  accommodates           5555 non-null   int64
#  23  bedrooms               5550 non-null   float64
#  24  beds                   5542 non-null   float64
#  25  number_of_reviews      5555 non-null   int64
#  26  bathrooms              5545 non-null   float64
#  27  amenities              5555 non-null   object
#  28  price                  5555 non-null   int64
#  29  security_deposit       3471 non-null   float64
#  30  cleaning_fee           4024 non-null   float64
#  31  extra_people           5555 non-null   int64
#  32  guests_included        5555 non-null   int64
#  33  images                 5555 non-null   object
#  34  host                   5555 non-null   object
#  35  address                5555 non-null   object
#  36  availability           5555 non-null   object
#  37  review_scores          5555 non-null   object
#  38  reviews                5555 non-null   object
#  39  weekly_price           714 non-null    float64
#  40  monthly_price          656 non-null    float64
#  41  reviews_per_month      94 non-null     float64
# dtypes: float64(8), int64(8), object(26)
# memory usage: 1.8+ MB

# %% [markdown]
# #extracting date from json file

# %%
path='/Users/rathikakn/Desktop/Guvi/project3airbnb'
filename=os.listdir(path)

for i in filename:
    filepath = os.path.join(path, i)
    with open(filepath, 'r', encoding='utf-8') as file:
        try:
            data_list = json.load(file)
            if isinstance(data_list, list):
                for i in data_list:
                    # Process data as before
                    ...
        except (json.JSONDecodeError, UnicodeDecodeError) as e:
            print(f"Error decoding JSON file {filepath}: {e}")
            continue  # Skip to the next file
# Out:
# Error decoding JSON file /Users/rathikakn/Desktop/Guvi/project3airbnb/.DS_Store: 'utf-8' codec can't decode byte 0xff in position 1068: invalid start byte
# Error decoding JSON file /Users/rathikakn/Desktop/Guvi/project3airbnb/pngkey.com-airbnb-logo-png-605967.png: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Error decoding JSON file /Users/rathikakn/Desktop/Guvi/project3airbnb/airbnbproject.csv: Expecting value: line 1 column 1 (char 0)
# Error decoding JSON file /Users/rathikakn/Desktop/Guvi/project3airbnb/airbnbimage.png: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Error decoding JSON file /Users/rathikakn/Desktop/Guvi/project3airbnb/2.py: Expecting value: line 1 column 1 (char 0)
# Error decoding JSON file /Users/rathikakn/Desktop/Guvi/project3airbnb/3.py: Expecting value: line 1 column 1 (char 0)
# Error decoding JSON file /Users/rathikakn/Desktop/Guvi/project3airbnb/airbnb_logo_detail.jpg: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
# Error decoding JSON file /Users/rathikakn/Desktop/Guvi/project3airbnb/project3.py: Expecting value: line 1 column 1 (char 0)
# Error decoding JSON file /Users/rathikakn/Desktop/Guvi/project3airbnb/abc.jpeg: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte

# %%
path='/Users/rathikakn/Desktop/Guvi/project3airbnb'
filename=os.listdir(path)

airbnb_data=[]

for i in filename:
    filepath=os.path.join(path,i)
    with open(filepath, 'r',encoding='latin-1') as file:
        try:
            data_list = json.load(file)
            if isinstance(data_list, list):
                for i in data_list:
                    data = {
                        "Listing_Id": i.get('_id'),
                        "Listing_url": i.get('listing_url'),
                        "Name": i.get('name'),
                        "Summary":i.get('summary'),
                        "Space":i.get('space'),
                        "Description": i.get('description'),
                        "Neighbourhood":i.get('neighborhood_overview'),
                        "Customer_notes":i.get('notes'),
                        "Transit":i.get('transit'),
                        "access":i.get('access'),
                        "interaction":i.get('interaction'),
                        "bathrooms":i.get('bathrooms'),
                        "monthly_price":i.get('monthly_price'),
                        "weekly_price":i.get('weekly_price'),                        
                        "House_rules": i.get('house_rules'),
                        "Property_type": i.get('property_type'),
                        "Room_type": i.get('room_type'),
                        "Bed_type": i.get('bed_type'),
                        "Min_nights": int(i.get('minimum_nights')),
                        "Max_nights": int(i.get('maximum_nights')),
                        "Cancellation_policy": i.get('cancellation_policy'),
                        "Accomodates": i.get('accommodates'),
                        "Total_bedrooms": i.get('bedrooms'),
                        "Total_beds": i.get('beds'),
                        "Availability": i.get('availability'),
                        "Availability_30": i['availability'].get('availability_30'),
                        "Availability_60": i['availability'].get('availability_60'),
                        "Availability_90": i['availability'].get('availability_90'),                        
                        "Availability_365": i['availability'].get('availability_365'),
                        "Price": float(i.get('price')),
                        "Security_deposit": i.get('security_deposit'),
                        "Cleaning_fee": i.get('cleaning_fee'),
                        "Extra_people": float(i.get('extra_people')),
                        "Guests_included": float(i.get('guests_included')),
                        "No_of_reviews": i.get('number_of_reviews'),
                        "Review_scores": i['review_scores'].get('review_scores_rating'),
                        "Review_scores_accuracy": i['review_scores'].get("review_scores_accuracy"),
                        "Review_scores_cleanliness": i['review_scores'].get("review_scores_cleanliness"),
                        "Review_scores_checkin": i['review_scores'].get("review_scores_checkin"),
                        "Review_scores_communication": i['review_scores'].get("review_scores_communication"),
                        "Review_scores_location": i['review_scores'].get("review_scores_location"),
                        "Review_scores_value": i['review_scores'].get("review_scores_value"),
                        "Amenities": ', '.join(i.get('amenities', [])),
                        "images":i['images'].get('picture_url'),
                        "Host_id": i['host'].get('host_id'),
                        "Host_name": i['host'].get('host_name'),
                        "Host_url": i['host'].get('host_url'),
                        "Host_location": i['host'].get('host_location'),
                        "Host_thumbnail_url": i['host'].get('host_thumbnail_url'),
                        "Host_response_rate": i['host'].get('host_response_rate'),
                        "Host_picture_url": i['host'].get('host_picture_url'),
                        "Host_neighbourhood": i['host'].get('host_neighbourhood'),
                        "Host_is_superhost": i['host'].get('host_is_superhost'),
                        "Host_has_profile_pic": i['host'].get('host_has_profile_pic'),
                        "Host_identity_verified": i['host'].get('host_identity_verified'),
                        "Host_listings_count": i['host'].get('host_listings_count'),
                        "Host_total_listings_count": i['host'].get('host_total_listings_count'),
                        "Host_verifications": i['host'].get('host_verifications'),
                        "Street": i['address'].get('street'),
                        "Country": i['address'].get('country'),
                        "Country_code": i['address'].get('country_code'),
                        "Location_type": i['address']['location'].get('type'),
                        "Longitude": i['address']['location']['coordinates'][0],
                        "Latitude": i['address']['location']['coordinates'][1],
                        "Is_location_exact": i['address']['location'].get('is_location_exact'),
                        "suburb": i['address'].get('suburb'),
                        "government_area": i['address'].get('government_area'),
                        "market": i['address'].get('market')
                    }
                    airbnb_data.append(data)

        except json.JSONDecodeError:
            print(f"error in opening json file:{filepath}")
# Out:
# error in opening json file:/Users/rathikakn/Desktop/Guvi/project3airbnb/.DS_Store
# error in opening json file:/Users/rathikakn/Desktop/Guvi/project3airbnb/pngkey.com-airbnb-logo-png-605967.png
# error in opening json file:/Users/rathikakn/Desktop/Guvi/project3airbnb/airbnbproject.csv
# error in opening json file:/Users/rathikakn/Desktop/Guvi/project3airbnb/airbnbimage.png
# error in opening json file:/Users/rathikakn/Desktop/Guvi/project3airbnb/2.py
# error in opening json file:/Users/rathikakn/Desktop/Guvi/project3airbnb/3.py
# error in opening json file:/Users/rathikakn/Desktop/Guvi/project3airbnb/airbnb_logo_detail.jpg
# error in opening json file:/Users/rathikakn/Desktop/Guvi/project3airbnb/project3.py
# error in opening json file:/Users/rathikakn/Desktop/Guvi/project3airbnb/abc.jpeg

# %%
df1=pd.DataFrame(airbnb_data)
df1
# Out:
#      Listing_Id                            Listing_url  \
# 0       1003530   https://www.airbnb.com/rooms/1003530
# 1      10133554  https://www.airbnb.com/rooms/10133554
# 2      10059872  https://www.airbnb.com/rooms/10059872
# 3      10084023  https://www.airbnb.com/rooms/10084023
# 4      10091713  https://www.airbnb.com/rooms/10091713
# ...         ...                                    ...
# 5550    9985696   https://www.airbnb.com/rooms/9985696
# 5551    9993190   https://www.airbnb.com/rooms/9993190
# 5552    9887054   https://www.airbnb.com/rooms/9887054
# 5553    9907907   https://www.airbnb.com/rooms/9907907
# 5554    9936016   https://www.airbnb.com/rooms/9936016
#
#                                                    Name  \
# 0                   New York City - Upper West Side Apt
# 1                   Double and triple rooms Blue mosque
# 2                    Soho Cozy, Spacious and Convenient
# 3                     City center private room with bed
# 4      Surry Hills Studio - Your Perfect Base in Sydney
# ...                                                 ...
# 5550                                    Kadıköy-Altıyol
# 5551  Just Steps from the Ocean at Premier Platinum ...
# 5552                Quarry Bay fully furnished studio C
# 5553                         Large double room in Bondi
# 5554                        Alugo Apartamento na Tijuca
#
#                                                 Summary  \
# 0
# 1
# 2     Clean, fully furnish, Spacious 1 bedroom flat ...
# 3     House is located 5mins walk from Sham Shui Po ...
# 4     This spacious, light filled studio has everyth...
# ...                                                 ...
# 5550  Kadıköy merkezde 2+1 dairem vardır.Çok kalabal...
# 5551  Relax Hawaiian Style in Gated Community on Oce...
# 5552   Newly renovated studio flat with full furniture.
# 5553  A bright large double room is available in a b...
# 5554  Apartamento amplo que acomoda 6 pessoas. Um qu...
#
#                                                   Space  \
# 0     Murphy bed, optional second bedroom available....
# 1     We are on the central city  Blue mosque 5 minu...
# 2
# 3     The house is old fashion type, and paint the w...
# 4     Comfortable studio with a great layout. The ba...
# ...                                                 ...
# 5550
# 5551  ***NOTE: THE OCEAN INFINITY POOL ("POOL 1"0 WI...
# 5552
# 5553
# 5554
#
#                                             Description  \
# 0     Murphy bed, optional second bedroom available....
# 1     We are on the central city  Blue mosque 5 minu...
# 2     Clean, fully furnish, Spacious 1 bedroom flat ...
# 3     House is located 5mins walk from Sham Shui Po ...
# 4     This spacious, light filled studio has everyth...
# ...                                                 ...
# 5550  Kadıköy merkezde 2+1 dairem vardır.Çok kalabal...
# 5551  Relax Hawaiian Style in Gated Community on Oce...
# 5552   Newly renovated studio flat with full furniture.
# 5553  A bright large double room is available in a b...
# 5554  Apartamento amplo que acomoda 6 pessoas. Um qu...
#
#                                           Neighbourhood  \
# 0     Great neighborhood - many terrific restaurants...
# 1     Cankurtaran mahallesi akbıyık caddesi no 22 Su...
# 2
# 3     Cheapest food, electronic device, clothing and...
# 4     Surry Hills is a vibrant eclectic community an...
# ...                                                 ...
# 5550
# 5551  Location: Located at the south end of Lahaina ...
# 5552
# 5553
# 5554
#
#                                          Customer_notes  \
# 0     My cat, Samantha, are in and out during the su...
# 1
# 2
# 3     Deposit of $1000 will be charged and will retu...
# 4     WiFi, Apple TV with Netflix App (for use with ...
# ...                                                 ...
# 5550
# 5551  Puamana Resort requires a $10/day resort fee w...
# 5552
# 5553
# 5554
#
#                                                 Transit  \
# 0     Conveniently located near 1, 2, 3, B & C subwa...
# 1      Tram 5 minutes  metro 10 minutes  Bus 10 minutes
# 2
# 3     Close to 3 different MTR Station, Sham shui Po...
# 4     Travel Card 'Opal' travel cards work on all Sy...
# ...                                                 ...
# 5550
# 5551  You can walk to most attractions within Lahain...
# 5552
# 5553  The flat is exactly half way between the shops...
# 5554
#
#                                                  access  ...  \
# 0                                        New York City!  ...
# 1     We have bathroom,wc,İnternet in rooms and unde...  ...
# 2                                                        ...
# 3     Living Room , Kitchen and Toilet, All cooking ...  ...
# 4     You have full use of the entire studio and com...  ...
# ...                                                 ...  ...
# 5550                                                     ...
# 5551  Guests will have access to the 3 pools in the ...  ...
# 5552                                                     ...
# 5553  Guests will have access to the full residence,...  ...
# 5554                                                     ...
#
#                                       Street        Country  Country_code  \
# 0                New York, NY, United States  United States            US
# 1                   Fatih , İstanbul, Turkey         Turkey            TR
# 2     Hong Kong, Hong Kong Island, Hong Kong      Hong Kong            HK
# 3                  Hong Kong , 九龍, Hong Kong      Hong Kong            HK
# 4                Surry Hills, NSW, Australia      Australia            AU
# ...                                      ...            ...           ...
# 5550               Kadıköy, İstanbul, Turkey         Turkey            TR
# 5551              Lahaina, HI, United States  United States            US
# 5552  Hong Kong, Hong Kong Island, Hong Kong      Hong Kong            HK
# 5553             Bondi Beach, NSW, Australia      Australia            AU
# 5554  Rio de Janeiro, Rio de Janeiro, Brazil         Brazil            BR
#
#       Location_type   Longitude   Latitude Is_location_exact  \
# 0             Point  -73.965230  40.799620             False
# 1             Point   28.980090  41.006200             False
# 2             Point  114.150270  22.281580              True
# 3             Point  114.166900  22.331400              True
# 4             Point  151.215540 -33.880290              True
# ...             ...         ...        ...               ...
# 5550          Point   29.030790  40.985630             False
# 5551          Point -156.667520  20.858940             False
# 5552          Point  114.207220  22.291570             False
# 5553          Point  151.265420 -33.892980             False
# 5554          Point  -43.173761 -22.908336             False
#
#                           suburb    government_area          market
# 0                      Manhattan    Upper West Side        New York
# 1                          Fatih              Fatih        Istanbul
# 2     Central & Western District  Central & Western       Hong Kong
# 3          Sham Shui Po District       Sham Shui Po       Hong Kong
# 4                   Darlinghurst             Sydney          Sydney
# ...                          ...                ...             ...
# 5550                        Moda            Kadikoy        Istanbul
# 5551                     Lahaina            Lahaina            Maui
# 5552                  Quarry Bay            Eastern       Hong Kong
# 5553                       Bondi           Waverley          Sydney
# 5554                        Lapa             Centro  Rio De Janeiro
#
# [5555 rows x 68 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 68 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Listing_Id                   5555 non-null   object
#  1   Listing_url                  5555 non-null   object
#  2   Name                         5555 non-null   object
#  3   Summary                      5555 non-null   object
#  4   Space                        5555 non-null   object
#  5   Description                  5555 non-null   object
#  6   Neighbourhood                5555 non-null   object
#  7   Customer_notes               5555 non-null   object
#  8   Transit                      5555 non-null   object
#  9   access                       5555 non-null   object
#  10  interaction                  5555 non-null   object
#  11  bathrooms                    5545 non-null   float64
#  12  monthly_price                656 non-null    float64
#  13  weekly_price                 714 non-null    float64
#  14  House_rules                  5555 non-null   object
#  15  Property_type                5555 non-null   object
#  16  Room_type                    5555 non-null   object
#  17  Bed_type                     5555 non-null   object
#  18  Min_nights                   5555 non-null   int64
#  19  Max_nights                   5555 non-null   int64
#  20  Cancellation_policy          5555 non-null   object
#  21  Accomodates                  5555 non-null   int64
#  22  Total_bedrooms               5550 non-null   float64
#  23  Total_beds                   5542 non-null   float64
#  24  Availability                 5555 non-null   object
#  25  Availability_30              5555 non-null   int64
#  26  Availability_60              5555 non-null   int64
#  27  Availability_90              5555 non-null   int64
#  28  Availability_365             5555 non-null   int64
#  29  Price                        5555 non-null   float64
#  30  Security_deposit             3471 non-null   float64
#  31  Cleaning_fee                 4024 non-null   float64
#  32  Extra_people                 5555 non-null   float64
#  33  Guests_included              5555 non-null   float64
#  34  No_of_reviews                5555 non-null   int64
#  35  Review_scores                4081 non-null   float64
#  36  Review_scores_accuracy       4079 non-null   float64
#  37  Review_scores_cleanliness    4082 non-null   float64
#  38  Review_scores_checkin        4080 non-null   float64
#  39  Review_scores_communication  4081 non-null   float64
#  40  Review_scores_location       4081 non-null   float64
#  41  Review_scores_value          4080 non-null   float64
#  42  Amenities                    5555 non-null   object
#  43  images                       5555 non-null   object
#  44  Host_id                      5555 non-null   object
#  45  Host_name                    5555 non-null   object
#  46  Host_url                     5555 non-null   object
#  47  Host_location                5555 non-null   object
#  48  Host_thumbnail_url           5555 non-null   object
#  49  Host_response_rate           4167 non-null   float64
#  50  Host_picture_url             5555 non-null   object
#  51  Host_neighbourhood           5555 non-null   object
#  52  Host_is_superhost            5555 non-null   bool
#  53  Host_has_profile_pic         5555 non-null   bool
#  54  Host_identity_verified       5555 non-null   bool
#  55  Host_listings_count          5555 non-null   int64
#  56  Host_total_listings_count    5555 non-null   int64
#  57  Host_verifications           5555 non-null   object
#  58  Street                       5555 non-null   object
#  59  Country                      5555 non-null   object
#  60  Country_code                 5555 non-null   object
#  61  Location_type                5555 non-null   object
#  62  Longitude                    5555 non-null   float64
#  63  Latitude                     5555 non-null   float64
#  64  Is_location_exact            5555 non-null   bool
#  65  suburb                       5555 non-null   object
#  66  government_area              5555 non-null   object
#  67  market                       5555 non-null   object
# dtypes: bool(4), float64(20), int64(10), object(34)
# memory usage: 2.7+ MB

# %%
df1.isna().sum()
# Out:
# Listing_Id           0
# Listing_url          0
# Name                 0
# Summary              0
# Space                0
#                     ..
# Latitude             0
# Is_location_exact    0
# suburb               0
# government_area      0
# market               0
# Length: 68, dtype: int64

# %%
df1.isna().sum()
# Out:
# Listing_Id           0
# Listing_url          0
# Name                 0
# Summary              0
# Space                0
#                     ..
# Latitude             0
# Is_location_exact    0
# suburb               0
# government_area      0
# market               0
# Length: 68, dtype: int64

# %%
df1[['bathrooms','monthly_price','weekly_price','Total_bedrooms','Total_beds','Security_deposit','Cleaning_fee','Review_scores']].mean()
# Out:
# bathrooms              1.291163
# monthly_price       5391.370427
# weekly_price        1530.903361
# Total_bedrooms         1.411712
# Total_beds             2.071454
# Security_deposit     509.430424
# Cleaning_fee          94.074801
# Review_scores         93.099240
# dtype: float64

# %%
#df1[['bathrooms','monthly_price','weekly_price','Total_bedrooms','Total_beds','Security_deposit','Cleaning_fee','Review_scores']].median()

# %%
#df1[['bathrooms','monthly_price','weekly_price','Total_bedrooms','Total_beds','Security_deposit','Cleaning_fee','Review_scores']].mode()

# %%
df1=df1.fillna({'bathrooms':df1["bathrooms"].mean(),
            'monthly_price': df1["monthly_price"].mean(),
            'weekly_price': df1["weekly_price"].mean(),
            'Total_bedrooms': df1["Total_bedrooms"].mean(),
            'Total_beds': df1["Total_beds"].mean(),
            'Security_deposit': df1["Security_deposit"].mean(),
            'Cleaning_fee': df1["Cleaning_fee"].mean(),
            'Host_response_rate':df1["Host_response_rate"].mean(),
            'Review_scores': df1["Review_scores"].mean()})

# %%
df1.isna().sum()
# Out:
# Listing_Id           0
# Listing_url          0
# Name                 0
# Summary              0
# Space                0
#                     ..
# Latitude             0
# Is_location_exact    0
# suburb               0
# government_area      0
# market               0
# Length: 68, dtype: int64

# %%
# CHECKING FOR EMPTY VALUES IN COLUMN

columns_with_empty_strings = df1.eq('').any()
columns_with_empty_strings = columns_with_empty_strings[columns_with_empty_strings].index
print("Columns with empty strings:", columns_with_empty_strings.tolist())
# Out:
# Columns with empty strings: ['Name', 'Summary', 'Space', 'Description', 'Neighbourhood', 'Customer_notes', 'Transit', 'access', 'interaction', 'House_rules', 'Amenities', 'Host_location', 'Host_neighbourhood', 'suburb', 'market']

# %%
# Filling Empty values in Description and House rules columns

df1.replace({
             "Summary": {'': 'No Data Found'},
             "Space": {'': ' No Data Found'},
             "Description": {'': 'No Data Found'},
             "Neighbourhood": {'': 'No Data Found'},
             "Customer_notes": {'': 'No Data Found'},
             "Transit": {'': 'No Data Found'},
             "access": {'': ' No Data Found'},
             "interaction": {'': ' No Data Found'},
             "House_rules": {'': 'No Data Found'},
             "Amenities": {'': 'No Data Found'},
             "Host_location": {'': 'No Data Found'},
             "Host_neighbourhood": {'': 'No Data Found'}, 
             "suburb": {'': 'No Data Found'}, 
             "market": {'': 'No Data Found'}
             }, inplace=True)

# %%
columns_with_empty_strings = df1.eq('').any()
columns_with_empty_strings = columns_with_empty_strings[columns_with_empty_strings].index
print("Columns with empty strings:", columns_with_empty_strings.tolist())
# Out:
# Columns with empty strings: ['Name']

# %%
df1
# Out:
#      Listing_Id                            Listing_url  \
# 0       1003530   https://www.airbnb.com/rooms/1003530
# 1      10133554  https://www.airbnb.com/rooms/10133554
# 2      10059872  https://www.airbnb.com/rooms/10059872
# 3      10084023  https://www.airbnb.com/rooms/10084023
# 4      10091713  https://www.airbnb.com/rooms/10091713
# ...         ...                                    ...
# 5550    9985696   https://www.airbnb.com/rooms/9985696
# 5551    9993190   https://www.airbnb.com/rooms/9993190
# 5552    9887054   https://www.airbnb.com/rooms/9887054
# 5553    9907907   https://www.airbnb.com/rooms/9907907
# 5554    9936016   https://www.airbnb.com/rooms/9936016
#
#                                                    Name  \
# 0                   New York City - Upper West Side Apt
# 1                   Double and triple rooms Blue mosque
# 2                    Soho Cozy, Spacious and Convenient
# 3                     City center private room with bed
# 4      Surry Hills Studio - Your Perfect Base in Sydney
# ...                                                 ...
# 5550                                    Kadıköy-Altıyol
# 5551  Just Steps from the Ocean at Premier Platinum ...
# 5552                Quarry Bay fully furnished studio C
# 5553                         Large double room in Bondi
# 5554                        Alugo Apartamento na Tijuca
#
#                                                 Summary  \
# 0                                         No Data Found
# 1                                         No Data Found
# 2     Clean, fully furnish, Spacious 1 bedroom flat ...
# 3     House is located 5mins walk from Sham Shui Po ...
# 4     This spacious, light filled studio has everyth...
# ...                                                 ...
# 5550  Kadıköy merkezde 2+1 dairem vardır.Çok kalabal...
# 5551  Relax Hawaiian Style in Gated Community on Oce...
# 5552   Newly renovated studio flat with full furniture.
# 5553  A bright large double room is available in a b...
# 5554  Apartamento amplo que acomoda 6 pessoas. Um qu...
#
#                                                   Space  \
# 0     Murphy bed, optional second bedroom available....
# 1     We are on the central city  Blue mosque 5 minu...
# 2                                         No Data Found
# 3     The house is old fashion type, and paint the w...
# 4     Comfortable studio with a great layout. The ba...
# ...                                                 ...
# 5550                                      No Data Found
# 5551  ***NOTE: THE OCEAN INFINITY POOL ("POOL 1"0 WI...
# 5552                                      No Data Found
# 5553                                      No Data Found
# 5554                                      No Data Found
#
#                                             Description  \
# 0     Murphy bed, optional second bedroom available....
# 1     We are on the central city  Blue mosque 5 minu...
# 2     Clean, fully furnish, Spacious 1 bedroom flat ...
# 3     House is located 5mins walk from Sham Shui Po ...
# 4     This spacious, light filled studio has everyth...
# ...                                                 ...
# 5550  Kadıköy merkezde 2+1 dairem vardır.Çok kalabal...
# 5551  Relax Hawaiian Style in Gated Community on Oce...
# 5552   Newly renovated studio flat with full furniture.
# 5553  A bright large double room is available in a b...
# 5554  Apartamento amplo que acomoda 6 pessoas. Um qu...
#
#                                           Neighbourhood  \
# 0     Great neighborhood - many terrific restaurants...
# 1     Cankurtaran mahallesi akbıyık caddesi no 22 Su...
# 2                                         No Data Found
# 3     Cheapest food, electronic device, clothing and...
# 4     Surry Hills is a vibrant eclectic community an...
# ...                                                 ...
# 5550                                      No Data Found
# 5551  Location: Located at the south end of Lahaina ...
# 5552                                      No Data Found
# 5553                                      No Data Found
# 5554                                      No Data Found
#
#                                          Customer_notes  \
# 0     My cat, Samantha, are in and out during the su...
# 1                                         No Data Found
# 2                                         No Data Found
# 3     Deposit of $1000 will be charged and will retu...
# 4     WiFi, Apple TV with Netflix App (for use with ...
# ...                                                 ...
# 5550                                      No Data Found
# 5551  Puamana Resort requires a $10/day resort fee w...
# 5552                                      No Data Found
# 5553                                      No Data Found
# 5554                                      No Data Found
#
#                                                 Transit  \
# 0     Conveniently located near 1, 2, 3, B & C subwa...
# 1      Tram 5 minutes  metro 10 minutes  Bus 10 minutes
# 2                                         No Data Found
# 3     Close to 3 different MTR Station, Sham shui Po...
# 4     Travel Card 'Opal' travel cards work on all Sy...
# ...                                                 ...
# 5550                                      No Data Found
# 5551  You can walk to most attractions within Lahain...
# 5552                                      No Data Found
# 5553  The flat is exactly half way between the shops...
# 5554                                      No Data Found
#
#                                                  access  ...  \
# 0                                        New York City!  ...
# 1     We have bathroom,wc,İnternet in rooms and unde...  ...
# 2                                         No Data Found  ...
# 3     Living Room , Kitchen and Toilet, All cooking ...  ...
# 4     You have full use of the entire studio and com...  ...
# ...                                                 ...  ...
# 5550                                      No Data Found  ...
# 5551  Guests will have access to the 3 pools in the ...  ...
# 5552                                      No Data Found  ...
# 5553  Guests will have access to the full residence,...  ...
# 5554                                      No Data Found  ...
#
#                                       Street        Country  Country_code  \
# 0                New York, NY, United States  United States            US
# 1                   Fatih , İstanbul, Turkey         Turkey            TR
# 2     Hong Kong, Hong Kong Island, Hong Kong      Hong Kong            HK
# 3                  Hong Kong , 九龍, Hong Kong      Hong Kong            HK
# 4                Surry Hills, NSW, Australia      Australia            AU
# ...                                      ...            ...           ...
# 5550               Kadıköy, İstanbul, Turkey         Turkey            TR
# 5551              Lahaina, HI, United States  United States            US
# 5552  Hong Kong, Hong Kong Island, Hong Kong      Hong Kong            HK
# 5553             Bondi Beach, NSW, Australia      Australia            AU
# 5554  Rio de Janeiro, Rio de Janeiro, Brazil         Brazil            BR
#
#       Location_type   Longitude   Latitude Is_location_exact  \
# 0             Point  -73.965230  40.799620             False
# 1             Point   28.980090  41.006200             False
# 2             Point  114.150270  22.281580              True
# 3             Point  114.166900  22.331400              True
# 4             Point  151.215540 -33.880290              True
# ...             ...         ...        ...               ...
# 5550          Point   29.030790  40.985630             False
# 5551          Point -156.667520  20.858940             False
# 5552          Point  114.207220  22.291570             False
# 5553          Point  151.265420 -33.892980             False
# 5554          Point  -43.173761 -22.908336             False
#
#                           suburb    government_area          market
# 0                      Manhattan    Upper West Side        New York
# 1                          Fatih              Fatih        Istanbul
# 2     Central & Western District  Central & Western       Hong Kong
# 3          Sham Shui Po District       Sham Shui Po       Hong Kong
# 4                   Darlinghurst             Sydney          Sydney
# ...                          ...                ...             ...
# 5550                        Moda            Kadikoy        Istanbul
# 5551                     Lahaina            Lahaina            Maui
# 5552                  Quarry Bay            Eastern       Hong Kong
# 5553                       Bondi           Waverley          Sydney
# 5554                        Lapa             Centro  Rio De Janeiro
#
# [5555 rows x 68 columns]

# %%
df1.dtypes
# Out:
# Listing_Id            object
# Listing_url           object
# Name                  object
# Summary               object
# Space                 object
#                       ...
# Latitude             float64
# Is_location_exact       bool
# suburb                object
# government_area       object
# market                object
# Length: 68, dtype: object

# %%
#changing data types
df1["Listing_Id"]=df1["Listing_Id"].astype(np.int64)
df1["Extra_people"]= df1["Extra_people"].astype(int)
df1["Total_bedrooms"]= df1["Total_bedrooms"].astype(int)
df1["bathrooms"]= df1["bathrooms"].astype(int)
df1["monthly_price"]= df1["monthly_price"].astype(int)
df1["weekly_price"]= df1["weekly_price"].astype(int)
df1["Total_beds"]= df1["Total_beds"].astype(int)
df1["Price"]= df1["Price"].astype(int)
df1["Security_deposit"]=df1["Security_deposit"].astype(int)
df1["Cleaning_fee"]= df1["Cleaning_fee"].astype(int)
df1["Guests_included"]= df1["Guests_included"].astype(int)
df1["Review_scores"]=df1["Review_scores"].astype(int)
df1["Host_id"]=df1["Host_id"].astype(np.int64)
df1["Review_scores_accuracy"]=df1["Host_id"].astype(np.float64)
df1["Review_scores_cleanliness"]=df1["Host_id"].astype(np.float64)
df1["Review_scores_checkin"]=df1["Host_id"].astype(np.float64)
df1["Review_scores_communication"]=df1["Host_id"].astype(np.float64)
df1["Review_scores_location"]=df1["Host_id"].astype(np.float64)
df1["Review_scores_value"]=df1["Host_id"].astype(np.float64)

# %%
df1.dtypes
# Out:
# Listing_Id             int64
# Listing_url           object
# Name                  object
# Summary               object
# Space                 object
#                       ...
# Latitude             float64
# Is_location_exact       bool
# suburb                object
# government_area       object
# market                object
# Length: 68, dtype: object

# %%
df1['Amenities'].unique()
# Out:
# array(['Internet, Wifi, Air conditioning, Kitchen, Elevator, Buzzer/wireless intercom, Heating, Family/kid friendly, Washer, Dryer, translation missing: en.hosting_amenity_50',
#        'Internet, Wifi, Air conditioning, Free parking on premises, Smoking allowed, Heating, Family/kid friendly, Suitable for events, Washer, Dryer, Fire extinguisher, Essentials, Shampoo, Hangers, Hair dryer, Iron, Laptop friendly workspace, Self check-in, Building staff',
#        'Air conditioning, Kitchen, Smoking allowed, Doorman, Elevator, Heating, Family/kid friendly, Essentials, 24-hour check-in, translation missing: en.hosting_amenity_50',
#        ...,
#        'TV, Wifi, Air conditioning, Kitchen, Elevator, Hot tub, Essentials, Lock on bedroom door, 24-hour check-in, Laptop friendly workspace, translation missing: en.hosting_amenity_49, translation missing: en.hosting_amenity_50',
#        'TV, Internet, Wifi, Kitchen, Washer, Dryer, Smoke detector, Essentials, Hangers',
#        'TV, Cable TV, Internet, Wifi, Air conditioning, Kitchen, Pets allowed, Pets live on this property, Dog(s), Buzzer/wireless intercom, Family/kid friendly, Washer, Hangers, Iron'],
#       dtype=object)

# %%
df1[['Listing_Id', 'Amenities']]
# Out:
#       Listing_Id                                          Amenities
# 0        1003530  Internet, Wifi, Air conditioning, Kitchen, Ele...
# 1       10133554  Internet, Wifi, Air conditioning, Free parking...
# 2       10059872  Air conditioning, Kitchen, Smoking allowed, Do...
# 3       10084023  TV, Wifi, Air conditioning, Kitchen, Elevator,...
# 4       10091713  TV, Wifi, Kitchen, Elevator, Heating, Washer, ...
# ...          ...                                                ...
# 5550     9985696  TV, Cable TV, Internet, Wifi, Kitchen, Buzzer/...
# 5551     9993190  TV, Wifi, Air conditioning, Pool, Kitchen, Fre...
# 5552     9887054  TV, Wifi, Air conditioning, Kitchen, Elevator,...
# 5553     9907907  TV, Internet, Wifi, Kitchen, Washer, Dryer, Sm...
# 5554     9936016  TV, Cable TV, Internet, Wifi, Air conditioning...
#
# [5555 rows x 2 columns]

# %%
df1['Review_scores'].describe()
# Out:
# count    5555.000000
# mean       93.072907
# std         7.734074
# min        20.000000
# 25%        93.000000
# 50%        93.000000
# 75%        98.000000
# max       100.000000
# Name: Review_scores, dtype: float64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 68 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Listing_Id                   5555 non-null   int64
#  1   Listing_url                  5555 non-null   object
#  2   Name                         5555 non-null   object
#  3   Summary                      5555 non-null   object
#  4   Space                        5555 non-null   object
#  5   Description                  5555 non-null   object
#  6   Neighbourhood                5555 non-null   object
#  7   Customer_notes               5555 non-null   object
#  8   Transit                      5555 non-null   object
#  9   access                       5555 non-null   object
#  10  interaction                  5555 non-null   object
#  11  bathrooms                    5555 non-null   int64
#  12  monthly_price                5555 non-null   int64
#  13  weekly_price                 5555 non-null   int64
#  14  House_rules                  5555 non-null   object
#  15  Property_type                5555 non-null   object
#  16  Room_type                    5555 non-null   object
#  17  Bed_type                     5555 non-null   object
#  18  Min_nights                   5555 non-null   int64
#  19  Max_nights                   5555 non-null   int64
#  20  Cancellation_policy          5555 non-null   object
#  21  Accomodates                  5555 non-null   int64
#  22  Total_bedrooms               5555 non-null   int64
#  23  Total_beds                   5555 non-null   int64
#  24  Availability                 5555 non-null   object
#  25  Availability_30              5555 non-null   int64
#  26  Availability_60              5555 non-null   int64
#  27  Availability_90              5555 non-null   int64
#  28  Availability_365             5555 non-null   int64
#  29  Price                        5555 non-null   int64
#  30  Security_deposit             5555 non-null   int64
#  31  Cleaning_fee                 5555 non-null   int64
#  32  Extra_people                 5555 non-null   int64
#  33  Guests_included              5555 non-null   int64
#  34  No_of_reviews                5555 non-null   int64
#  35  Review_scores                5555 non-null   int64
#  36  Review_scores_accuracy       5555 non-null   float64
#  37  Review_scores_cleanliness    5555 non-null   float64
#  38  Review_scores_checkin        5555 non-null   float64
#  39  Review_scores_communication  5555 non-null   float64
#  40  Review_scores_location       5555 non-null   float64
#  41  Review_scores_value          5555 non-null   float64
#  42  Amenities                    5555 non-null   object
#  43  images                       5555 non-null   object
#  44  Host_id                      5555 non-null   int64
#  45  Host_name                    5555 non-null   object
#  46  Host_url                     5555 non-null   object
#  47  Host_location                5555 non-null   object
#  48  Host_thumbnail_url           5555 non-null   object
#  49  Host_response_rate           5555 non-null   float64
#  50  Host_picture_url             5555 non-null   object
#  51  Host_neighbourhood           5555 non-null   object
#  52  Host_is_superhost            5555 non-null   bool
#  53  Host_has_profile_pic         5555 non-null   bool
#  54  Host_identity_verified       5555 non-null   bool
#  55  Host_listings_count          5555 non-null   int64
#  56  Host_total_listings_count    5555 non-null   int64
#  57  Host_verifications           5555 non-null   object
#  58  Street                       5555 non-null   object
#  59  Country                      5555 non-null   object
#  60  Country_code                 5555 non-null   object
#  61  Location_type                5555 non-null   object
#  62  Longitude                    5555 non-null   float64
#  63  Latitude                     5555 non-null   float64
#  64  Is_location_exact            5555 non-null   bool
#  65  suburb                       5555 non-null   object
#  66  government_area              5555 non-null   object
#  67  market                       5555 non-null   object
# dtypes: bool(4), float64(9), int64(23), object(32)
# memory usage: 2.7+ MB

# %%
df1[['Review_scores', 'Review_scores_accuracy','Review_scores_cleanliness','Review_scores_checkin','Review_scores_communication','Review_scores_location','Review_scores_value']]
# Out:
#       Review_scores  Review_scores_accuracy  Review_scores_cleanliness  \
# 0                94                454250.0                   454250.0
# 1                92              52004703.0                 52004703.0
# 2               100              51624384.0                 51624384.0
# 3                92              51744313.0                 51744313.0
# 4                95              13764143.0                 13764143.0
# ...             ...                     ...                        ...
# 5550             93              51303748.0                 51303748.0
# 5551             92              51013381.0                 51013381.0
# 5552             85              31386255.0                 31386255.0
# 5553             93              47615848.0                 47615848.0
# 5554             93              47092481.0                 47092481.0
#
#       Review_scores_checkin  Review_scores_communication  \
# 0                  454250.0                     454250.0
# 1                52004703.0                   52004703.0
# 2                51624384.0                   51624384.0
# 3                51744313.0                   51744313.0
# 4                13764143.0                   13764143.0
# ...                     ...                          ...
# 5550             51303748.0                   51303748.0
# 5551             51013381.0                   51013381.0
# 5552             31386255.0                   31386255.0
# 5553             47615848.0                   47615848.0
# 5554             47092481.0                   47092481.0
#
#       Review_scores_location  Review_scores_value
# 0                   454250.0             454250.0
# 1                 52004703.0           52004703.0
# 2                 51624384.0           51624384.0
# 3                 51744313.0           51744313.0
# 4                 13764143.0           13764143.0
# ...                      ...                  ...
# 5550              51303748.0           51303748.0
# 5551              51013381.0           51013381.0
# 5552              31386255.0           31386255.0
# 5553              47615848.0           47615848.0
# 5554              47092481.0           47092481.0
#
# [5555 rows x 7 columns]

# %%
df1[['Review_scores', 'Review_scores_accuracy','Review_scores_cleanliness','Review_scores_checkin','Review_scores_communication','Review_scores_location','Review_scores_value']].median()
# Out:
# Review_scores                        93.0
# Review_scores_accuracy         37256846.0
# Review_scores_cleanliness      37256846.0
# Review_scores_checkin          37256846.0
# Review_scores_communication    37256846.0
# Review_scores_location         37256846.0
# Review_scores_value            37256846.0
# dtype: float64

# %%
df1.loc[(df1['Review_scores_accuracy'].isna())] = df1['Review_scores_accuracy'].median()
df1.loc[(df1['Review_scores_cleanliness'].isna())] = df1['Review_scores_cleanliness'].median()
df1.loc[(df1['Review_scores_checkin'].isna())] = df1['Review_scores_checkin'].median()
df1.loc[(df1['Review_scores_communication'].isna())] = df1['Review_scores_communication'].median()
df1.loc[(df1['Review_scores_location'].isna())] = df1['Review_scores_location'].median()
df1.loc[(df1['Review_scores_value'].isna())] = df1['Review_scores_value'].median()

# %%
df1['Property_type'].unique()
# Out:
# array(['Apartment', 'Bed and breakfast', 'Guesthouse', 'Hostel',
#        'Serviced apartment', 'Loft', 'House', 'Condominium', 'Treehouse',
#        'Guest suite', 'Bungalow', 'Townhouse', 'Villa', 'Cabin', 'Other',
#        'Farm stay', 'Chalet', 'Boutique hotel', 'Cottage', 'Boat',
#        'Earth house', 'Aparthotel', 'Resort', 'Tiny house',
#        'Nature lodge', 'Hotel', 'Camper/RV', 'Casa particular (Cuba)',
#        'Barn', 'Hut', 'Heritage hotel (India)', 'Pension (South Korea)',
#        'Campsite', 'Castle', 'Houseboat', 'Train'], dtype=object)

# %%
df1['Property_type'] = df1['Property_type'].str.lower()
df1['Property_type'].unique()
# Out:
# array(['apartment', 'bed and breakfast', 'guesthouse', 'hostel',
#        'serviced apartment', 'loft', 'house', 'condominium', 'treehouse',
#        'guest suite', 'bungalow', 'townhouse', 'villa', 'cabin', 'other',
#        'farm stay', 'chalet', 'boutique hotel', 'cottage', 'boat',
#        'earth house', 'aparthotel', 'resort', 'tiny house',
#        'nature lodge', 'hotel', 'camper/rv', 'casa particular (cuba)',
#        'barn', 'hut', 'heritage hotel (india)', 'pension (south korea)',
#        'campsite', 'castle', 'houseboat', 'train'], dtype=object)

# %%
mappings = {'apartment':'apartment', 
            'bed and breakfast':'hostel', 
            'guesthouse':'house', 
            'hostel':'hostel',
            'serviced apartment':'apartment', 
            'loft':'hostel', 
            'house':'guesthouse', 
            'condominium':'apartment', 
            'treehouse':'treehouse',
            'guest suite':'guest suite', 
            'bungalow':'bungalow', 
            'townhouse':'house', 
            'villa':'villa', 
            'cabin':'cabin', 
            'other':'other',
            'farm stay':'farm stay', 
            'chalet':'cabin', 
            'boutique hotel':'hotel', 
            'cottage':'house', 
            'boat':'boat house',
            'earth house':'house', 
            'aparthotel':'apartment', 
            'resort':'resort', 
            'tiny house':'house',
            'nature lodge':'camp', 
            'hotel':'hotel', 
            'camper/rv':'camp', 
            'casa particular (cuba)':'casa particular (cuba)',
            'barn':'hut', 
            'hut':'hut', 
            'heritage hotel (india)':'heritage hotel (india)', 
            'pension (south korea)':'pension (south korea)',
            'campsite':'camp', 
            'castle':'castle', 
            'houseboat':'boat house', 
            'train':'train stay'
            }

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 68 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Listing_Id                   5555 non-null   int64
#  1   Listing_url                  5555 non-null   object
#  2   Name                         5555 non-null   object
#  3   Summary                      5555 non-null   object
#  4   Space                        5555 non-null   object
#  5   Description                  5555 non-null   object
#  6   Neighbourhood                5555 non-null   object
#  7   Customer_notes               5555 non-null   object
#  8   Transit                      5555 non-null   object
#  9   access                       5555 non-null   object
#  10  interaction                  5555 non-null   object
#  11  bathrooms                    5555 non-null   int64
#  12  monthly_price                5555 non-null   int64
#  13  weekly_price                 5555 non-null   int64
#  14  House_rules                  5555 non-null   object
#  15  Property_type                5555 non-null   object
#  16  Room_type                    5555 non-null   object
#  17  Bed_type                     5555 non-null   object
#  18  Min_nights                   5555 non-null   int64
#  19  Max_nights                   5555 non-null   int64
#  20  Cancellation_policy          5555 non-null   object
#  21  Accomodates                  5555 non-null   int64
#  22  Total_bedrooms               5555 non-null   int64
#  23  Total_beds                   5555 non-null   int64
#  24  Availability                 5555 non-null   object
#  25  Availability_30              5555 non-null   int64
#  26  Availability_60              5555 non-null   int64
#  27  Availability_90              5555 non-null   int64
#  28  Availability_365             5555 non-null   int64
#  29  Price                        5555 non-null   int64
#  30  Security_deposit             5555 non-null   int64
#  31  Cleaning_fee                 5555 non-null   int64
#  32  Extra_people                 5555 non-null   int64
#  33  Guests_included              5555 non-null   int64
#  34  No_of_reviews                5555 non-null   int64
#  35  Review_scores                5555 non-null   int64
#  36  Review_scores_accuracy       5555 non-null   float64
#  37  Review_scores_cleanliness    5555 non-null   float64
#  38  Review_scores_checkin        5555 non-null   float64
#  39  Review_scores_communication  5555 non-null   float64
#  40  Review_scores_location       5555 non-null   float64
#  41  Review_scores_value          5555 non-null   float64
#  42  Amenities                    5555 non-null   object
#  43  images                       5555 non-null   object
#  44  Host_id                      5555 non-null   int64
#  45  Host_name                    5555 non-null   object
#  46  Host_url                     5555 non-null   object
#  47  Host_location                5555 non-null   object
#  48  Host_thumbnail_url           5555 non-null   object
#  49  Host_response_rate           5555 non-null   float64
#  50  Host_picture_url             5555 non-null   object
#  51  Host_neighbourhood           5555 non-null   object
#  52  Host_is_superhost            5555 non-null   bool
#  53  Host_has_profile_pic         5555 non-null   bool
#  54  Host_identity_verified       5555 non-null   bool
#  55  Host_listings_count          5555 non-null   int64
#  56  Host_total_listings_count    5555 non-null   int64
#  57  Host_verifications           5555 non-null   object
#  58  Street                       5555 non-null   object
#  59  Country                      5555 non-null   object
#  60  Country_code                 5555 non-null   object
#  61  Location_type                5555 non-null   object
#  62  Longitude                    5555 non-null   float64
#  63  Latitude                     5555 non-null   float64
#  64  Is_location_exact            5555 non-null   bool
#  65  suburb                       5555 non-null   object
#  66  government_area              5555 non-null   object
#  67  market                       5555 non-null   object
# dtypes: bool(4), float64(9), int64(23), object(32)
# memory usage: 2.7+ MB

# %%
df1['Longitude'].isnull().sum()
# Out:
# 0

# %%
df1.to_csv("airbnbproject.csv",index=False)

# %%
df2=pd.read_csv("/Users/rathikakn/Desktop/Guvi/project3airbnb/airbnbproject.csv")

# %%
df2
# Out:
#       Listing_Id                            Listing_url  \
# 0        1003530   https://www.airbnb.com/rooms/1003530
# 1       10133554  https://www.airbnb.com/rooms/10133554
# 2       10059872  https://www.airbnb.com/rooms/10059872
# 3       10084023  https://www.airbnb.com/rooms/10084023
# 4       10091713  https://www.airbnb.com/rooms/10091713
# ...          ...                                    ...
# 5550     9985696   https://www.airbnb.com/rooms/9985696
# 5551     9993190   https://www.airbnb.com/rooms/9993190
# 5552     9887054   https://www.airbnb.com/rooms/9887054
# 5553     9907907   https://www.airbnb.com/rooms/9907907
# 5554     9936016   https://www.airbnb.com/rooms/9936016
#
#                                                    Name  \
# 0                   New York City - Upper West Side Apt
# 1                   Double and triple rooms Blue mosque
# 2                    Soho Cozy, Spacious and Convenient
# 3                     City center private room with bed
# 4      Surry Hills Studio - Your Perfect Base in Sydney
# ...                                                 ...
# 5550                                    Kadıköy-Altıyol
# 5551  Just Steps from the Ocean at Premier Platinum ...
# 5552                Quarry Bay fully furnished studio C
# 5553                         Large double room in Bondi
# 5554                        Alugo Apartamento na Tijuca
#
#                                                 Summary  \
# 0                                         No Data Found
# 1                                         No Data Found
# 2     Clean, fully furnish, Spacious 1 bedroom flat ...
# 3     House is located 5mins walk from Sham Shui Po ...
# 4     This spacious, light filled studio has everyth...
# ...                                                 ...
# 5550  Kadıköy merkezde 2+1 dairem vardır.Çok kalabal...
# 5551  Relax Hawaiian Style in Gated Community on Oce...
# 5552   Newly renovated studio flat with full furniture.
# 5553  A bright large double room is available in a b...
# 5554  Apartamento amplo que acomoda 6 pessoas. Um qu...
#
#                                                   Space  \
# 0     Murphy bed, optional second bedroom available....
# 1     We are on the central city  Blue mosque 5 minu...
# 2                                         No Data Found
# 3     The house is old fashion type, and paint the w...
# 4     Comfortable studio with a great layout. The ba...
# ...                                                 ...
# 5550                                      No Data Found
# 5551  ***NOTE: THE OCEAN INFINITY POOL ("POOL 1"0 WI...
# 5552                                      No Data Found
# 5553                                      No Data Found
# 5554                                      No Data Found
#
#                                             Description  \
# 0     Murphy bed, optional second bedroom available....
# 1     We are on the central city  Blue mosque 5 minu...
# 2     Clean, fully furnish, Spacious 1 bedroom flat ...
# 3     House is located 5mins walk from Sham Shui Po ...
# 4     This spacious, light filled studio has everyth...
# ...                                                 ...
# 5550  Kadıköy merkezde 2+1 dairem vardır.Çok kalabal...
# 5551  Relax Hawaiian Style in Gated Community on Oce...
# 5552   Newly renovated studio flat with full furniture.
# 5553  A bright large double room is available in a b...
# 5554  Apartamento amplo que acomoda 6 pessoas. Um qu...
#
#                                           Neighbourhood  \
# 0     Great neighborhood - many terrific restaurants...
# 1     Cankurtaran mahallesi akbıyık caddesi no 22 Su...
# 2                                         No Data Found
# 3     Cheapest food, electronic device, clothing and...
# 4     Surry Hills is a vibrant eclectic community an...
# ...                                                 ...
# 5550                                      No Data Found
# 5551  Location: Located at the south end of Lahaina ...
# 5552                                      No Data Found
# 5553                                      No Data Found
# 5554                                      No Data Found
#
#                                          Customer_notes  \
# 0     My cat, Samantha, are in and out during the su...
# 1                                         No Data Found
# 2                                         No Data Found
# 3     Deposit of $1000 will be charged and will retu...
# 4     WiFi, Apple TV with Netflix App (for use with ...
# ...                                                 ...
# 5550                                      No Data Found
# 5551  Puamana Resort requires a $10/day resort fee w...
# 5552                                      No Data Found
# 5553                                      No Data Found
# 5554                                      No Data Found
#
#                                                 Transit  \
# 0     Conveniently located near 1, 2, 3, B & C subwa...
# 1      Tram 5 minutes  metro 10 minutes  Bus 10 minutes
# 2                                         No Data Found
# 3     Close to 3 different MTR Station, Sham shui Po...
# 4     Travel Card 'Opal' travel cards work on all Sy...
# ...                                                 ...
# 5550                                      No Data Found
# 5551  You can walk to most attractions within Lahain...
# 5552                                      No Data Found
# 5553  The flat is exactly half way between the shops...
# 5554                                      No Data Found
#
#                                                  access  ...  \
# 0                                        New York City!  ...
# 1     We have bathroom,wc,İnternet in rooms and unde...  ...
# 2                                         No Data Found  ...
# 3     Living Room , Kitchen and Toilet, All cooking ...  ...
# 4     You have full use of the entire studio and com...  ...
# ...                                                 ...  ...
# 5550                                      No Data Found  ...
# 5551  Guests will have access to the 3 pools in the ...  ...
# 5552                                      No Data Found  ...
# 5553  Guests will have access to the full residence,...  ...
# 5554                                      No Data Found  ...
#
#                                       Street        Country  Country_code  \
# 0                New York, NY, United States  United States            US
# 1                   Fatih , İstanbul, Turkey         Turkey            TR
# 2     Hong Kong, Hong Kong Island, Hong Kong      Hong Kong            HK
# 3                  Hong Kong , 九龍, Hong Kong      Hong Kong            HK
# 4                Surry Hills, NSW, Australia      Australia            AU
# ...                                      ...            ...           ...
# 5550               Kadıköy, İstanbul, Turkey         Turkey            TR
# 5551              Lahaina, HI, United States  United States            US
# 5552  Hong Kong, Hong Kong Island, Hong Kong      Hong Kong            HK
# 5553             Bondi Beach, NSW, Australia      Australia            AU
# 5554  Rio de Janeiro, Rio de Janeiro, Brazil         Brazil            BR
#
#       Location_type   Longitude   Latitude Is_location_exact  \
# 0             Point  -73.965230  40.799620             False
# 1             Point   28.980090  41.006200             False
# 2             Point  114.150270  22.281580              True
# 3             Point  114.166900  22.331400              True
# 4             Point  151.215540 -33.880290              True
# ...             ...         ...        ...               ...
# 5550          Point   29.030790  40.985630             False
# 5551          Point -156.667520  20.858940             False
# 5552          Point  114.207220  22.291570             False
# 5553          Point  151.265420 -33.892980             False
# 5554          Point  -43.173761 -22.908336             False
#
#                           suburb    government_area          market
# 0                      Manhattan    Upper West Side        New York
# 1                          Fatih              Fatih        Istanbul
# 2     Central & Western District  Central & Western       Hong Kong
# 3          Sham Shui Po District       Sham Shui Po       Hong Kong
# 4                   Darlinghurst             Sydney          Sydney
# ...                          ...                ...             ...
# 5550                        Moda            Kadikoy        Istanbul
# 5551                     Lahaina            Lahaina            Maui
# 5552                  Quarry Bay            Eastern       Hong Kong
# 5553                       Bondi           Waverley          Sydney
# 5554                        Lapa             Centro  Rio De Janeiro
#
# [5555 rows x 68 columns]
